# %% [markdown]
# Purpose:
# A deep mutational scanning experiment was performed on the Hrd1 ubiquitin ligase to determine residues required for wild-type function and find mutations specifically required for ERAD-L degradation.
# This notebook shows use of a python script “BAM_Translation_v2.5.py” that translates the bowtie2 Hrd1 aligned reads and outputs a fasta file of translated protein sequences. The second script “Mutation_Analysis_v2.4.py” takes the translated protein fasta file and determines locations of amino acid mutations compared to the wild-type Hrd1 amino acid sequence; the output is mutational count tables of “Single”, “Multi”, and “All” (counts of both single and multiple mutations), frequency of mutations in library, and list of multiple mutations.

# %%
##ouput python version, pysam, Biopython, pandas version (Libraries used for the two python scripts).
import pysam
import Bio
import pandas
import sys

print('Python version:',sys.version)
print('Pysam version:',pysam.__version__)
print('Biopython version:',Bio.__version__)
print('Pandas version:',pandas.__version__)
# Out:
# Python version: 3.7.16 (default, Jan 17 2023, 22:20:44)
# [GCC 11.2.0]
# Pysam version: 0.15.3
# Biopython version: 1.76
# Pandas version: 1.0.1

# %%
import os

##python scripts location
py_dir = 'py_files/'
trans_py = str(py_dir+'BAM_Translation_v2.5.py')
mut_py = str(py_dir+'Mutation_Analysis_v2.4.py')

##input (bam_dir) and then output folder names
bam_dir = '3_bowtie/'
trans_dir = '4_translation/'
mut_dir = '5_mutation/'

if not os.path.isdir(trans_dir):
    os.mkdir(trans_dir)
if not os.path.isdir(mut_dir):
    os.mkdir(mut_dir)
    
##text file containing bam file anmes that are input for translation python script; single filename per line
in_f = 'Hrd1_Translation_Input_Name.txt'

with open(in_f,'r') as file:
    header = file.readline()
    for x in file:
        bam_name = x.strip('\n')
        base_name = bam_name[:-10]
        bam_in = str(bam_dir+bam_name)
        trans_out = str(trans_dir+base_name+'_trans.fa')
        ##not bad, but reads that didn't pass filters
        bad_trans = str(trans_dir+base_name+'_BadReads.tsv')
        analysis_out = str(mut_dir+base_name)

        '''
        Run translation script
        Arguments:
        1) bam_in = file location of bam file
        2) trans_out = file location of output translated protein sequences
        3) 90 = location of "A" in ATG start codon in Hrd1 reference used for bowtie2 alignment
        4) 1745 = location of third base in stop codon in Hrd1 reference used for bowtie2 alignment
        5) 330 = min length (basepairs) of sequencing read
        '''
        # !python $trans_py $bam_in $trans_out $bad_trans 90 1745 330
        '''
        Run mutational analysis script
        Arguments:
        1) trans_out = file location of input translated protein sequences
        2) Hrd1-AA.fa = fasta file that is Hrd1 reference protein sequence
        3) analysis_out = base file name for output from script 
        4) Y = include wildtype amino acid counts in the codon count tables;        
        '''
        # !python $mut_py $trans_out Hrd1-AA.fa $analysis_out Y
# Out:
# 3_bowtie/Hrd1_DMS_Rep1_Region1_Input_align.bam 4_translation/Hrd1_DMS_Rep1_Region1_Input_trans.fa 4_translation/Hrd1_DMS_Rep1_Region1_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region1_Input_align.bam 171197 9539 7724 0 0 76 380
# 3_bowtie/Hrd1_DMS_Rep2_Region1_Input_align.bam 4_translation/Hrd1_DMS_Rep2_Region1_Input_trans.fa 4_translation/Hrd1_DMS_Rep2_Region1_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region1_Input_align.bam 146550 4396 7008 0 0 1 125
# 3_bowtie/Hrd1_DMS_Rep3_Region1_Input_align.bam 4_translation/Hrd1_DMS_Rep3_Region1_Input_trans.fa 4_translation/Hrd1_DMS_Rep3_Region1_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region1_Input_align.bam 177226 1922 7316 0 0 161 356
# 3_bowtie/Hrd1_DMS_Rep4_Region1_Input_align.bam 4_translation/Hrd1_DMS_Rep4_Region1_Input_trans.fa 4_translation/Hrd1_DMS_Rep4_Region1_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region1_Input_align.bam 103415 577 3961 0 0 0 59
# 3_bowtie/Hrd1_DMS_Rep1_Region1_WT_align.bam 4_translation/Hrd1_DMS_Rep1_Region1_WT_trans.fa 4_translation/Hrd1_DMS_Rep1_Region1_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region1_WT_align.bam 190338 22 4232 0 0 85 361
# 3_bowtie/Hrd1_DMS_Rep2_Region1_WT_align.bam 4_translation/Hrd1_DMS_Rep2_Region1_WT_trans.fa 4_translation/Hrd1_DMS_Rep2_Region1_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region1_WT_align.bam 156412 15 3733 0 0 0 110
# 3_bowtie/Hrd1_DMS_Rep3_Region1_WT_align.bam 4_translation/Hrd1_DMS_Rep3_Region1_WT_trans.fa 4_translation/Hrd1_DMS_Rep3_Region1_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region1_WT_align.bam 121993 11 3110 0 0 64 157
# 3_bowtie/Hrd1_DMS_Rep4_Region1_WT_align.bam 4_translation/Hrd1_DMS_Rep4_Region1_WT_trans.fa 4_translation/Hrd1_DMS_Rep4_Region1_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region1_WT_align.bam 128810 10 3025 0 0 0 41
# 3_bowtie/Hrd1_DMS_Rep1_Region1_LDead_align.bam 4_translation/Hrd1_DMS_Rep1_Region1_LDead_trans.fa 4_translation/Hrd1_DMS_Rep1_Region1_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region1_LDead_align.bam 74759 6 1628 0 0 32 165
# 3_bowtie/Hrd1_DMS_Rep2_Region1_LDead_align.bam 4_translation/Hrd1_DMS_Rep2_Region1_LDead_trans.fa 4_translation/Hrd1_DMS_Rep2_Region1_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region1_LDead_align.bam 79288 10 1867 0 0 0 66
# 3_bowtie/Hrd1_DMS_Rep3_Region1_LDead_align.bam 4_translation/Hrd1_DMS_Rep3_Region1_LDead_trans.fa 4_translation/Hrd1_DMS_Rep3_Region1_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region1_LDead_align.bam 10472 3 256 0 0 8 24
# 3_bowtie/Hrd1_DMS_Rep4_Region1_LDead_align.bam 4_translation/Hrd1_DMS_Rep4_Region1_LDead_trans.fa 4_translation/Hrd1_DMS_Rep4_Region1_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region1_LDead_align.bam 9921 1 276 0 0 0 5
# 3_bowtie/Hrd1_DMS_Rep1_Region2_Input_align.bam 4_translation/Hrd1_DMS_Rep1_Region2_Input_trans.fa 4_translation/Hrd1_DMS_Rep1_Region2_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region2_Input_align.bam 209572 26225 7683 0 0 0 168
# 3_bowtie/Hrd1_DMS_Rep2_Region2_Input_align.bam 4_translation/Hrd1_DMS_Rep2_Region2_Input_trans.fa 4_translation/Hrd1_DMS_Rep2_Region2_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region2_Input_align.bam 104272 3482 3937 0 0 0 121
# 3_bowtie/Hrd1_DMS_Rep3_Region2_Input_align.bam 4_translation/Hrd1_DMS_Rep3_Region2_Input_trans.fa 4_translation/Hrd1_DMS_Rep3_Region2_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region2_Input_align.bam 249276 3749 7508 0 0 0 513
# 3_bowtie/Hrd1_DMS_Rep4_Region2_Input_align.bam 4_translation/Hrd1_DMS_Rep4_Region2_Input_trans.fa 4_translation/Hrd1_DMS_Rep4_Region2_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region2_Input_align.bam 202217 3647 5737 0 0 0 231
# 3_bowtie/Hrd1_DMS_Rep1_Region2_WT_align.bam 4_translation/Hrd1_DMS_Rep1_Region2_WT_trans.fa 4_translation/Hrd1_DMS_Rep1_Region2_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region2_WT_align.bam 197806 14 3351 0 0 0 162
# 3_bowtie/Hrd1_DMS_Rep2_Region2_WT_align.bam 4_translation/Hrd1_DMS_Rep2_Region2_WT_trans.fa 4_translation/Hrd1_DMS_Rep2_Region2_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region2_WT_align.bam 212249 28 3436 0 0 0 266
# 3_bowtie/Hrd1_DMS_Rep3_Region2_WT_align.bam 4_translation/Hrd1_DMS_Rep3_Region2_WT_trans.fa 4_translation/Hrd1_DMS_Rep3_Region2_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region2_WT_align.bam 151481 16 2425 0 0 0 237
# 3_bowtie/Hrd1_DMS_Rep4_Region2_WT_align.bam 4_translation/Hrd1_DMS_Rep4_Region2_WT_trans.fa 4_translation/Hrd1_DMS_Rep4_Region2_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region2_WT_align.bam 166331 18 2724 0 0 0 122
# 3_bowtie/Hrd1_DMS_Rep2_Region2_LDead_align.bam 4_translation/Hrd1_DMS_Rep2_Region2_LDead_trans.fa 4_translation/Hrd1_DMS_Rep2_Region2_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region2_LDead_align.bam 18516 10 313 0 0 0 18
# 3_bowtie/Hrd1_DMS_Rep3_Region2_LDead_align.bam 4_translation/Hrd1_DMS_Rep3_Region2_LDead_trans.fa 4_translation/Hrd1_DMS_Rep3_Region2_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region2_LDead_align.bam 12016 2 179 0 0 0 19
# 3_bowtie/Hrd1_DMS_Rep1_Region3_Input_align.bam 4_translation/Hrd1_DMS_Rep1_Region3_Input_trans.fa 4_translation/Hrd1_DMS_Rep1_Region3_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region3_Input_align.bam 198084 8727 9766 0 0 1 381
# 3_bowtie/Hrd1_DMS_Rep2_Region3_Input_align.bam 4_translation/Hrd1_DMS_Rep2_Region3_Input_trans.fa 4_translation/Hrd1_DMS_Rep2_Region3_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region3_Input_align.bam 198479 8049 9381 0 0 0 482
# 3_bowtie/Hrd1_DMS_Rep3_Region3_Input_align.bam 4_translation/Hrd1_DMS_Rep3_Region3_Input_trans.fa 4_translation/Hrd1_DMS_Rep3_Region3_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region3_Input_align.bam 212070 4246 5987 0 0 0 451
# 3_bowtie/Hrd1_DMS_Rep4_Region3_Input_align.bam 4_translation/Hrd1_DMS_Rep4_Region3_Input_trans.fa 4_translation/Hrd1_DMS_Rep4_Region3_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region3_Input_align.bam 177746 3513 4676 0 0 0 377
# 3_bowtie/Hrd1_DMS_Rep1_Region3_WT_align.bam 4_translation/Hrd1_DMS_Rep1_Region3_WT_trans.fa 4_translation/Hrd1_DMS_Rep1_Region3_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region3_WT_align.bam 209132 33 3780 0 0 0 409
# 3_bowtie/Hrd1_DMS_Rep2_Region3_WT_align.bam 4_translation/Hrd1_DMS_Rep2_Region3_WT_trans.fa 4_translation/Hrd1_DMS_Rep2_Region3_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region3_WT_align.bam 160923 21 3135 0 0 0 314
# 3_bowtie/Hrd1_DMS_Rep3_Region3_WT_align.bam 4_translation/Hrd1_DMS_Rep3_Region3_WT_trans.fa 4_translation/Hrd1_DMS_Rep3_Region3_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region3_WT_align.bam 180954 31 2685 0 0 0 325
# 3_bowtie/Hrd1_DMS_Rep4_Region3_WT_align.bam 4_translation/Hrd1_DMS_Rep4_Region3_WT_trans.fa 4_translation/Hrd1_DMS_Rep4_Region3_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region3_WT_align.bam 133847 18 1855 0 0 0 185
# 3_bowtie/Hrd1_DMS_Rep1_Region3_LDead_align.bam 4_translation/Hrd1_DMS_Rep1_Region3_LDead_trans.fa 4_translation/Hrd1_DMS_Rep1_Region3_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region3_LDead_align.bam 20959 4 249 0 0 0 44
# 3_bowtie/Hrd1_DMS_Rep4_Region3_LDead_align.bam 4_translation/Hrd1_DMS_Rep4_Region3_LDead_trans.fa 4_translation/Hrd1_DMS_Rep4_Region3_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region3_LDead_align.bam 9882 6 96 0 0 0 44
# 3_bowtie/Hrd1_DMS_Rep1_Region4_Input_align.bam 4_translation/Hrd1_DMS_Rep1_Region4_Input_trans.fa 4_translation/Hrd1_DMS_Rep1_Region4_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region4_Input_align.bam 204292 51579 3346 0 0 0 160
# 3_bowtie/Hrd1_DMS_Rep3_Region4_Input_align.bam 4_translation/Hrd1_DMS_Rep3_Region4_Input_trans.fa 4_translation/Hrd1_DMS_Rep3_Region4_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region4_Input_align.bam 221818 13813 5242 0 0 0 259
# 3_bowtie/Hrd1_DMS_Rep4_Region4_Input_align.bam 4_translation/Hrd1_DMS_Rep4_Region4_Input_trans.fa 4_translation/Hrd1_DMS_Rep4_Region4_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region4_Input_align.bam 208410 7220 4315 0 0 0 598
# 3_bowtie/Hrd1_DMS_Rep1_Region4_WT_align.bam 4_translation/Hrd1_DMS_Rep1_Region4_WT_trans.fa 4_translation/Hrd1_DMS_Rep1_Region4_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region4_WT_align.bam 203137 21 2072 0 0 0 208
# 3_bowtie/Hrd1_DMS_Rep3_Region4_WT_align.bam 4_translation/Hrd1_DMS_Rep3_Region4_WT_trans.fa 4_translation/Hrd1_DMS_Rep3_Region4_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region4_WT_align.bam 163042 27 2689 0 0 0 136
# 3_bowtie/Hrd1_DMS_Rep4_Region4_WT_align.bam 4_translation/Hrd1_DMS_Rep4_Region4_WT_trans.fa 4_translation/Hrd1_DMS_Rep4_Region4_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region4_WT_align.bam 133277 49 1688 0 0 1 300
# 3_bowtie/Hrd1_DMS_Rep1_Region4_LDead_align.bam 4_translation/Hrd1_DMS_Rep1_Region4_LDead_trans.fa 4_translation/Hrd1_DMS_Rep1_Region4_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region4_LDead_align.bam 21404 23 2413 0 0 0 19
# 3_bowtie/Hrd1_DMS_Rep3_Region4_LDead_align.bam 4_translation/Hrd1_DMS_Rep3_Region4_LDead_trans.fa 4_translation/Hrd1_DMS_Rep3_Region4_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region4_LDead_align.bam 11057 16 1333 0 0 0 15
# 3_bowtie/Hrd1_DMS_Rep4_Region4_LDead_align.bam 4_translation/Hrd1_DMS_Rep4_Region4_LDead_trans.fa 4_translation/Hrd1_DMS_Rep4_Region4_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region4_LDead_align.bam 10069 15 1104 0 0 0 35
# 3_bowtie/Hrd1_DMS_Rep1_Region5_Input_align.bam 4_translation/Hrd1_DMS_Rep1_Region5_Input_trans.fa 4_translation/Hrd1_DMS_Rep1_Region5_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region5_Input_align.bam 188067 4869 8281 0 0 0 418
# 3_bowtie/Hrd1_DMS_Rep2_Region5_Input_align.bam 4_translation/Hrd1_DMS_Rep2_Region5_Input_trans.fa 4_translation/Hrd1_DMS_Rep2_Region5_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region5_Input_align.bam 152207 3257 7287 0 0 204 142
# 3_bowtie/Hrd1_DMS_Rep3_Region5_Input_align.bam 4_translation/Hrd1_DMS_Rep3_Region5_Input_trans.fa 4_translation/Hrd1_DMS_Rep3_Region5_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region5_Input_align.bam 151123 681 5095 0 0 0 271
# 3_bowtie/Hrd1_DMS_Rep4_Region5_Input_align.bam 4_translation/Hrd1_DMS_Rep4_Region5_Input_trans.fa 4_translation/Hrd1_DMS_Rep4_Region5_Input_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region5_Input_align.bam 195712 561 6407 0 0 0 310
# 3_bowtie/Hrd1_DMS_Rep1_Region5_WT_align.bam 4_translation/Hrd1_DMS_Rep1_Region5_WT_trans.fa 4_translation/Hrd1_DMS_Rep1_Region5_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region5_WT_align.bam 146065 28 2826 0 0 0 211
# 3_bowtie/Hrd1_DMS_Rep2_Region5_WT_align.bam 4_translation/Hrd1_DMS_Rep2_Region5_WT_trans.fa 4_translation/Hrd1_DMS_Rep2_Region5_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region5_WT_align.bam 150069 30 3862 0 0 110 80
# 3_bowtie/Hrd1_DMS_Rep4_Region5_WT_align.bam 4_translation/Hrd1_DMS_Rep4_Region5_WT_trans.fa 4_translation/Hrd1_DMS_Rep4_Region5_WT_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region5_WT_align.bam 143913 13 2796 0 0 0 195
# 3_bowtie/Hrd1_DMS_Rep1_Region5_LDead_align.bam 4_translation/Hrd1_DMS_Rep1_Region5_LDead_trans.fa 4_translation/Hrd1_DMS_Rep1_Region5_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep1_Region5_LDead_align.bam 21914 3448 3233 0 0 0 34
# 3_bowtie/Hrd1_DMS_Rep2_Region5_LDead_align.bam 4_translation/Hrd1_DMS_Rep2_Region5_LDead_trans.fa 4_translation/Hrd1_DMS_Rep2_Region5_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep2_Region5_LDead_align.bam 21147 3460 3359 0 0 22 20
# 3_bowtie/Hrd1_DMS_Rep3_Region5_LDead_align.bam 4_translation/Hrd1_DMS_Rep3_Region5_LDead_trans.fa 4_translation/Hrd1_DMS_Rep3_Region5_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep3_Region5_LDead_align.bam 59389 59343 11 0 0 0 23
# 3_bowtie/Hrd1_DMS_Rep4_Region5_LDead_align.bam 4_translation/Hrd1_DMS_Rep4_Region5_LDead_trans.fa 4_translation/Hrd1_DMS_Rep4_Region5_LDead_BadReads.tsv 90 1745 330
# bam_in total_reads total_not_align total_indel total_softclip total_indel_softclip total_prom_term total_short
# 3_bowtie/Hrd1_DMS_Rep4_Region5_LDead_align.bam 47417 46859 149 0 0 0 7
